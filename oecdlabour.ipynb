# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
options(repr.plot.width=25, repr.plot.height=10)

# %%
devtools::install_github('Mikata-Project/ggthemr')
# Out:
# ...
# rlang  (1.0.5 -> 1.0.6) [CRAN]
# cli    (3.3.0 -> 3.4.1) [CRAN]
# vctrs  (0.4.1 -> 0.4.2) [CRAN]
# tibble (3.1.7 -> 3.1.8) [CRAN]
# Installing 4 packages: rlang, cli, vctrs, tibble
#
# Warning message:
# "package 'tibble' is in use and will not be installed"
# Installing packages into 'C:/Users/robbi/AppData/Local/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\robbi\AppData\Local\R\win-library\4.2\00LOCK\rlang\libs\x64\rlang.dll to C:\Users\robbi\AppData\Local\R\win-library\4.2\rlang\libs\x64\rlang.dll: Permission denied"
# Warning message:
# "restored 'rlang'"
# package 'cli' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'cli'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# ...

# %%
library(ggthemr)
# Out:
# Error in library(ggthemr): there is no package called 'ggthemr'
# Traceback:
#
# 1. library(ggthemr)

# %%
oecdlabour_df <- read.csv('https://stats.oecd.org/sdmx-json/data/DP_LIVE/.HRWKD.../OECD?contentType=csv&detail=code&separator=comma&csv-lang=en') #reads the file and assigns it to the variable bike_df
glimpse(oecdlabour_df) #the glimpse function allows us to have a peek at what the dataset will look like
# Out:
# Rows: 1,803
# Columns: 8
# $ LOCATION   <chr> "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AU…
# $ INDICATOR  <chr> "HRWKD", "HRWKD", "HRWKD", "HRWKD", "HRWKD", "HRWKD", "HRWK…
# $ SUBJECT    <chr> "TOT", "TOT", "TOT", "TOT", "TOT", "TOT", "TOT", "TOT", "TO…
# $ MEASURE    <chr> "HR_WKD", "HR_WKD", "HR_WKD", "HR_WKD", "HR_WKD", "HR_WKD",…
# $ FREQUENCY  <chr> "A", "A", "A", "A", "A", "A", "A", "A", "A", "A", "A", "A",…
# $ TIME       <int> 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,…
# $ Value      <dbl> 1876.000, 1877.000, 1889.000, 1885.000, 1875.000, 1853.000,…
# $ Flag.Codes <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA,…

# %%
oecdlabour_df
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY TIME Value    Flag.Codes
# 1    AUS      HRWKD     TOT     HR_WKD  A         1985 1876.000 NA
# 2    AUS      HRWKD     TOT     HR_WKD  A         1986 1877.000 NA
# 3    AUS      HRWKD     TOT     HR_WKD  A         1987 1889.000 NA
# 4    AUS      HRWKD     TOT     HR_WKD  A         1988 1885.000 NA
# 5    AUS      HRWKD     TOT     HR_WKD  A         1989 1875.000 NA
# 6    AUS      HRWKD     TOT     HR_WKD  A         1990 1853.000 NA
# 7    AUS      HRWKD     TOT     HR_WKD  A         1991 1854.038 NA
# 8    AUS      HRWKD     TOT     HR_WKD  A         1992 1845.604 NA
# 9    AUS      HRWKD     TOT     HR_WKD  A         1993 1855.744 NA
# 10   AUS      HRWKD     TOT     HR_WKD  A         1994 1874.227 NA
# 11   AUS      HRWKD     TOT     HR_WKD  A         1995 1870.308 NA
# 12   AUS      HRWKD     TOT     HR_WKD  A         1996 1861.517 NA
# 13   AUS      HRWKD     TOT     HR_WKD  A         1997 1860.848 NA
# ...

# %%
oecdlabour_df <- (oecdlabour_df %>% select(LOCATION, TIME, Value))
oecdlabour_df
# Out:
#      LOCATION TIME Value
# 1    AUS      1985 1876.000
# 2    AUS      1986 1877.000
# 3    AUS      1987 1889.000
# 4    AUS      1988 1885.000
# 5    AUS      1989 1875.000
# 6    AUS      1990 1853.000
# 7    AUS      1991 1854.038
# 8    AUS      1992 1845.604
# 9    AUS      1993 1855.744
# 10   AUS      1994 1874.227
# 11   AUS      1995 1870.308
# 12   AUS      1996 1861.517
# 13   AUS      1997 1860.848
# 14   AUS      1998 1849.882
# 15   AUS      1999 1856.080
# 16   AUS      2000 1852.162
# 17   AUS      2001 1828.685
# 18   AUS      2002 1817.956
# 19   AUS      2003 1806.503
# 20   AUS      2004 1811.396
# 21   AUS      2005 1807.904
# 22   AUS      2006 1802.431
# 23   AUS      2007 1803.099
# 24   AUS      2008 1799.053
# 25   AUS      2009 1766.654
# 26   AUS      2010 1777.571
# 27   AUS      2011 1773.895
# 28   AUS      2012 1770.775
# 29   AUS      2013 1766.009
# 30   AUS      2014 1755.133
# ⋮    ⋮        ⋮    ⋮
# 1774 ROU      2019 1803.112
# ...

# %%
median_hrs <- (oecdlabour_df %>% group_by(LOCATION) %>%
    summarise(median_value = median(Value)))
median_hrs
# Out:
#    LOCATION medianvalue
# 1  AUS      1811.396
# 2  AUT      1599.000
# 3  BEL      1593.000
# 4  BGR      1645.247
# 5  CAN      1790.000
# 6  CHE      1664.500
# 7  CHL      2233.500
# 8  COL      2283.913
# 9  CRI      2346.000
# 10 CYP      1847.256
# 11 CZE      1799.048
# 12 DEU      1443.400
# 13 DNK      1455.352
# 14 ESP      1753.800
# 15 EST      1790.500
# 16 EU27     1650.115
# 17 FIN      1676.000
# 18 FRA      1663.000
# 19 GBR      1579.105
# 20 GRC      1995.937
# 21 HRV      1923.105
# 22 HUN      1915.100
# 23 IRL      1958.500
# 24 ISL      1668.000
# 25 ISR      1947.200
# 26 ITA      1806.500
# 27 JPN      1887.923
# 28 KOR      2079.500
# 29 LTU      1654.940
# 30 LUX      1567.000
# 31 LVA      1751.084
# 32 MEX      2138.890
# 33 MLT      2119.115
# 34 NLD      1456.538
# 35 NOR      1495.850
# 36 NZL      1804.000
# 37 OECD     1845.561
# 38 POL      1854.695
# 39 PRT      1752.499
# 40 ROU      1837.060
# 41 RUS      1978.000
# 42 SVK      1774.000
# ...

# %%
filtered_oecd <- oecdlabour_df[oecdlabour_df$LOCATION %in% c('ISR', 'NLD', 'NZL', 'KOR', 'USA'),]
filtered_oecd
# Out:
#      LOCATION TIME Value
# 689  KOR      2008 2228
# 690  KOR      2009 2174
# 691  KOR      2010 2163
# 692  KOR      2011 2136
# 693  KOR      2012 2119
# 694  KOR      2013 2106
# 695  KOR      2014 2076
# 696  KOR      2015 2083
# 697  KOR      2016 2068
# 698  KOR      2017 2018
# 699  KOR      2018 1993
# 700  KOR      2019 1967
# 701  KOR      2020 1908
# 702  KOR      2021 1915
# 761  NLD      1970 1809
# 762  NLD      1971 1777
# 763  NLD      1972 1775
# 764  NLD      1973 1749
# 765  NLD      1974 1696
# 766  NLD      1975 1644
# 767  NLD      1976 1628
# 768  NLD      1977 1608
# 769  NLD      1978 1580
# 770  NLD      1979 1559
# 771  NLD      1980 1556
# 772  NLD      1981 1556
# 773  NLD      1982 1542
# 774  NLD      1983 1527
# 775  NLD      1984 1519
# 776  NLD      1985 1502
# ⋮    ⋮        ⋮    ⋮
# 1409 ISR      1992 1951.20
# 1410 ISR      1993 1953.00
# 1411 ISR      1994 1993.10
# 1412 ISR      1995 2013.80
# 1413 ISR      1996 2031.00
# ...

# %%
filtered_oecd %>% 
    ggplot(aes(x = TIME, y = Value, col=LOCATION, size=10)) + 
    geom_freqpoly(stat='identity') + #makes a barplot and makes the graph look nice
    labs(x = 'year', y = 'Hours Worked', title = '') #labels the graph accurately
# Out:
# plot without title

# %%
median_hrs %>%
    ggplot(aes(x=LOCATION, y=medianvalue)) +
    geom_bar(stat='identity') +
    theme_linedraw() +
    theme(text = element_text(size = 20))
# Out:
# plot without title
